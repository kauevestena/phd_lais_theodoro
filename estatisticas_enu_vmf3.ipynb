# %%
scenario = 'demo5_2h_orig'

# %%
import pandas as pd
import numpy as np
import os
import glob
from datetime import timedelta, datetime

# Função para ler o arquivo de coordenadas das estações RBMC
def read_rbmc_coordinates(file_path):
    columns = ['YearDay', 'Date', 'StationID', 'CoordSystem', 'StationName', 'StationCode',
               'X', 'Y', 'Z', 'StdX', 'StdY', 'StdZ']

    df = pd.read_csv(file_path, delim_whitespace=True, header=None, names=columns)
    df['Date'] = pd.to_datetime(df['Date'])
    df['X'] = df['X'].astype(float)
    df['Y'] = df['Y'].astype(float)
    df['Z'] = df['Z'].astype(float)
    df['StdX'] = df['StdX'].astype(float)
    df['StdY'] = df['StdY'].astype(float)
    df['StdZ'] = df['StdZ'].astype(float)

    return df

# Função para extrair os dados de processamento GNSS
def extract_data(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    data_lines = [line.strip() for line in lines if line[0].isdigit()]

    timestamps = []
    x_coords = []
    y_coords = []
    z_coords = []

    for line in data_lines:
        parts = line.split()
        timestamp = parts[0] + ' ' + parts[1]
        x = float(parts[2])
        y = float(parts[3])
        z = float(parts[4])

        timestamps.append(timestamp)
        x_coords.append(x)
        y_coords.append(y)
        z_coords.append(z)

    data = pd.DataFrame({
        'Timestamp': pd.to_datetime(timestamps),
        'X': x_coords,
        'Y': y_coords,
        'Z': z_coords
    })

    return data

# Função para calcular o RMSE
def calculate_rmse(predictions, true_values):
    return np.sqrt(np.mean((predictions - true_values) ** 2))

def doy_year_to_date(doy, year):
  """Converts day of year (DOY) and year to a date object.

  Args:
    doy: The day of year (1-366).
    year: The year (e.g., 2023).

  Returns:
    A datetime object representing the date.
  """
  date = datetime(year, 1, 1) + timedelta(days=doy - 1)
  return date

def get_closest_backward_date(query_date, datearray):
  """Finds the closest date in datearray that is less than or equal to query_date.

  Args:
    query_date: A pandas Timestamp object representing the query date.
    datearray: A pandas DatetimeIndex or Series representing the array of dates.

  Returns:
    A pandas Timestamp object representing the closest backward date, or None if
    no such date is found.
  """
  # Filter dates less than or equal to query_date
  valid_dates = datearray[datearray <= query_date]

  # If no valid dates are found, return None
  if valid_dates.empty:
    return None

  # Return the last (closest) valid date
  return valid_dates[-1]

def get_closest_date(query_date, datearray):
  """Finds the closest date in datearray to query_date.

  Args:
    query_date: A pandas Timestamp object representing the query date.
    datearray: A pandas DatetimeIndex or Series representing the array of dates.

  Returns:
    A pandas Timestamp object representing the closest date.
  """
  # Calculate absolute time differences
  time_diffs = abs(datearray - query_date)

  # Find the index of the minimum time difference
  closest_index = time_diffs.argmin()

  # Return the date at the closest index
  return datearray[closest_index]

# %%
# all_scenarios = ['orig','orig_nograd',"vmf3_grads","vmf3_nograd","actual_vmf3_grads",'vmf3_taylor','vmf3_grads_forward']

charts_path = 'charts'

# Caminho base dos arquivos
base_input_path = '/home/gnss_data/saidas'
# base_path = f'/content/drive/My Drive/VMF3/dados/{scenario}/'
base_path = os.path.join(base_input_path,scenario)

# Meses e estações RBMC
meses = ['VERAO', 'INVERNO']
estacoes_rbmc = ['BRAZ', 'CUIB', 'UFPR', 'NAUS', 'POAL', 'PERC', 'ONRJ', 'SSA1', 'SAGA', 'POLI']

# Caminho dos arquivos de coordenadas das estações
file_path_rbmc = 'Coordenadas_estacoes.txt'

# Lê os dados das coordenadas das estações RBMC
df_rbmc = read_rbmc_coordinates(file_path_rbmc)

# declarando o ano:
ano = 2020

# Define a data inicial e final para análise
# data_inicial = {'VERAO' : pd.Timestamp('2020-01-01'), "INVERNO" : pd.Timestamp('2020-06-01')}
# data_final = {'VERAO' : pd.Timestamp('2020-01-31'), "INVERNO" : pd.Timestamp('2020-07-31')}
# Out:
# /tmp/ipykernel_17330/2279821802.py:12: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, header=None, names=columns)

# %%
# CÉLULA PRA TESTAR A INTEGRIDADE DOS DADOS

for mes in meses:
    for estacao in estacoes_rbmc:
      file_path_gnss = os.path.join(base_path, mes, estacao, 'pos')

      filelist = os.listdir(file_path_gnss)
      total_files_pos_files = [f for f in filelist if not '.stat' in f]
      total_stat_files = [f for f in filelist if '.stat' in f]

      print(mes,estacao,len(total_files_pos_files),len(total_stat_files),len(filelist))
# Out:
# VERAO BRAZ 42 0 42
# VERAO CUIB 62 0 62
# VERAO UFPR 62 0 62
# VERAO NAUS 62 0 62
# VERAO POAL 62 0 62
# VERAO PERC 62 0 62
# VERAO ONRJ 62 0 62
# VERAO SSA1 62 0 62
# VERAO SAGA 62 0 62
# VERAO POLI 62 0 62
# INVERNO BRAZ 62 0 62
# INVERNO CUIB 16 0 16
# INVERNO UFPR 0 0 0
# INVERNO NAUS 0 0 0
# INVERNO POAL 0 0 0
# INVERNO PERC 0 0 0
# INVERNO ONRJ 0 0 0
# INVERNO SSA1 0 0 0
# INVERNO SAGA 0 0 0
# INVERNO POLI 0 0 0

# %%
unique_week_ref_dates = df_rbmc['Date'].unique()

unique_week_ref_dates
# Out:
# <DatetimeArray>
# ['2020-01-01 00:00:00', '2020-01-08 00:00:00', '2020-01-15 00:00:00',
#  '2020-01-22 00:00:00', '2020-01-29 00:00:00', '2020-07-01 00:00:00',
#  '2020-07-08 00:00:00', '2020-07-15 00:00:00', '2020-07-22 00:00:00',
#  '2020-07-29 00:00:00']
# Length: 10, dtype: datetime64[ns]

# %%
# for sc in all_scenarios:
os.makedirs(os.path.join(charts_path, scenario), exist_ok=True)
os.makedirs(os.path.join('saidas', scenario), exist_ok=True)
    
sc_outpath = os.path.join('saidas',scenario)
sc_charts_outpath = os.path.join(charts_path,scenario)

# %%
import pandas as pd
import numpy as np
import os
import glob
from datetime import timedelta, datetime

# Inicializa a lista para armazenar os resultados
results = []

# Itera sobre cada mês e estação RBMC
for mes in meses:
    for estacao in estacoes_rbmc:
        # Caminho dos arquivos de processamento GNSS
        file_path_gnss = os.path.join(base_path, mes, estacao, 'pos')

        # Encontre todos os arquivos .pos
        gnss_files = glob.glob(os.path.join(file_path_gnss, '*.pos'))

        for filepath in gnss_files:
            try:
                # Extrair o "day of year"
                doy = int(filepath.split('_')[-2][-4:-1])

                # Transformar DOY + ano em data
                doy_as_date = doy_year_to_date(doy, ano)

                # Data de referência semanal mais próxima
                ref_date = get_closest_date(doy_as_date, unique_week_ref_dates)

                # Coordenadas da estação
                station_coordinates = df_rbmc[
                    (df_rbmc['StationName'] == estacao) & (df_rbmc['Date'] == ref_date)
                ][['X', 'Y', 'Z']].values

                if station_coordinates.size == 0:
                    print(f"Sem coordenadas para {estacao} em {ref_date}. Pulando...")
                    continue

                # Processando o arquivo de resultados
                gnss_data = extract_data(filepath)

                # Calcula o RMSE para cada coordenada (X, Y, Z)
                rmse_x = calculate_rmse(gnss_data['X'].values, station_coordinates[0, 0])
                rmse_y = calculate_rmse(gnss_data['Y'].values, station_coordinates[0, 1])
                rmse_z = calculate_rmse(gnss_data['Z'].values, station_coordinates[0, 2])

                # Adiciona os resultados à lista
                results.append({
                    'Estacao': estacao,
                    'Periodo': mes,
                    'DOY': doy,
                    'DataReferencia': ref_date,
                    'RMSE_E': rmse_x,
                    'RMSE_N': rmse_y,
                    'RMSE_U': rmse_z
                })

            except Exception as e:
                print(f"Erro ao processar arquivo {filepath}: {e}")

# Cria um DataFrame com os resultados
df_results = pd.DataFrame(results)

# Exibe o resumo agrupado por estação e período
summary = df_results.groupby(['Estacao', 'Periodo']).mean(numeric_only=True)
print(summary)

# Salva os resultados em um arquivo CSV
# output_file = f'saidas/{scenario}/rmse_summary.csv'
output_file = os.path.join(sc_outpath,'rmse_summary.csv')
df_results.to_csv(output_file, index=False)
print(f"Resumo salvo em {output_file}")


actual_summary_path = os.path.join(sc_outpath,'rmse_general_summary.csv')
summary.to_csv(actual_summary_path, index=False)
# Out:
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1831_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1841_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1851_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1861_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1871_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1881_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1891_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1901_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1911_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1921_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1931_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1941_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1951_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1961_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1971_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1981_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1991_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2001_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1831_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1841_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1851_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1861_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1871_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1881_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1891_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1901_res_events.pos: invalid literal for int() with base 10: 're'
#                    DOY    RMSE_E    RMSE_N    RMSE_U
# Estacao Periodo
# BRAZ    INVERNO  198.0  0.320131  0.293997  0.178743
#         VERAO     21.0  0.282648  0.400849  0.219537
# CUIB    INVERNO  186.5  0.277572  0.214297  0.085614
#         VERAO     16.0  0.352722  0.245163  0.137307
# NAUS    VERAO     16.0  0.212038  0.308564  0.126119
# ONRJ    VERAO     16.0  0.354009  0.223552  0.175235
# PERC    VERAO     16.0  0.296895  0.278673  0.193061
# POAL    VERAO     16.0  0.247282  0.287306  0.221281
# POLI    VERAO     16.0  0.247544  0.363345  0.240600
# SAGA    VERAO     16.0  0.364778  0.386630  0.137501
# SSA1    VERAO     16.0  0.393738  0.254023  0.141640
# UFPR    VERAO     16.0  0.207657  0.414609  0.243746
# Resumo salvo em saidas/demo5_2h_orig/rmse_summary.csv

# %%
import pandas as pd
import numpy as np
import os
import glob
from datetime import timedelta, datetime

def textual_boxplot(df, columnname, outpath, subset_column=None, subset_value=None):
    if columnname not in df.columns:
        raise ValueError(f"Column '{columnname}' not found in DataFrame.")
    
    # Apply filtering if subset_column and subset_value are provided
    if subset_column and subset_value is not None:
        if subset_column not in df.columns:
            raise ValueError(f"Subset column '{subset_column}' not found in DataFrame.")
        df = df[df[subset_column] == subset_value]
    
    # Compute statistics
    Q1 = df[columnname].quantile(0.25)
    Q2 = df[columnname].median()
    Q3 = df[columnname].quantile(0.75)
    IQR = Q3 - Q1
    min_val = df[columnname].min()
    max_val = df[columnname].max()
    
    # Define potential outliers (values outside 1.5 * IQR)
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[columnname] < lower_bound) | (df[columnname] > upper_bound)][columnname].tolist()
    
    # Prepare output data
    boxplot_data = {
        "Metric": ["Minimum (Q0)", "Q1 (25%)", "Median (Q2)", "Q3 (75%)", "Maximum (Q4)", "IQR (Q3 - Q1)", "Lower Bound", "Upper Bound", "Outliers"],
        "Value": [min_val, Q1, Q2, Q3, max_val, IQR, lower_bound, upper_bound, ", ".join(map(str, outliers)) if outliers else "None"]
    }
    
    # Convert to DataFrame and save to CSV
    output_df = pd.DataFrame(boxplot_data)
    output_df.to_csv(outpath, index=False)
    
    
# Função para ler o arquivo de coordenadas geodésicas das estações RBMC
def read_rbmc_geodetic_coordinates(file_path):
    columns = ['YearDay', 'Date', 'StationID', 'CoordSystem', 'StationName', 'StationCode',
               'Latitude', 'Longitude', 'Height', 'StdLat', 'StdLon', 'StdHeight']

    df = pd.read_csv(file_path, delim_whitespace=True, header=None, names=columns)
    df['Date'] = pd.to_datetime(df['Date'])
    df['Latitude'] = df['Latitude'].astype(float)
    df['Longitude'] = df['Longitude'].astype(float)
    df['Height'] = df['Height'].astype(float)
    df['StdLat'] = df['StdLat'].astype(float)
    df['StdLon'] = df['StdLon'].astype(float)
    df['StdHeight'] = df['StdHeight'].astype(float)

    return df

# Função para calcular o RMSE
def calculate_rmse(predictions, true_values):
    return np.sqrt(np.mean((predictions - true_values) ** 2))

# Função para conversão de coordenadas cartesianas para geodésicas
def convert_cartesian_to_geodetic(x, y, z):
    # Define os parâmetros do elipsoide WGS84
    a = 6378137.0  # Raio equatorial em metros
    f = 1 / 298.257223563  # Flattening
    e2 = 2 * f - f**2  # Excentricidade quadrada

    # Calcula latitude, longitude e altura
    lon = np.arctan2(y, x)
    p = np.sqrt(x**2 + y**2)
    lat = np.arctan2(z, p * (1 - f))
    h = 0

    # Método iterativo para determinar a latitude
    for _ in range(5):
        sin_lat = np.sin(lat)
        N = a / np.sqrt(1 - e2 * sin_lat**2)
        h = p / np.cos(lat) - N
        lat = np.arctan2(z + e2 * N * sin_lat, p)

    lat_deg = np.degrees(lat)
    lon_deg = np.degrees(lon)
    return lat_deg, lon_deg, h

# Função para calcular RMSE no sistema geodésico local (SGL)
def calculate_rmse_sgl(gnss_data, station_geodetic, station_std, station_cartesian):
    # Diferenças entre as coordenadas
    DX = gnss_data['X'].values - station_cartesian[0, 0]
    DY = gnss_data['Y'].values - station_cartesian[0, 1]
    DZ = gnss_data['Z'].values - station_cartesian[0, 2]

    # Conversão para Sistema Geodésico Local
    lat_rbmc = np.radians(station_geodetic[0, 0])
    lon_rbmc = np.radians(station_geodetic[0, 1])

    SGL_matrix = np.array([[-np.sin(lon_rbmc), np.cos(lon_rbmc), 0],
                           [-np.sin(lat_rbmc)*np.cos(lon_rbmc), -np.sin(lat_rbmc)*np.sin(lon_rbmc), np.cos(lat_rbmc)],
                           [np.cos(lat_rbmc)*np.cos(lon_rbmc), np.cos(lat_rbmc)*np.sin(lon_rbmc), np.sin(lat_rbmc)]])
    SGL = np.dot(SGL_matrix, np.array([DX, DY, DZ]))

    # Extraindo componentes Leste, Norte e Altura
    de = SGL[0]
    dn = SGL[1]
    du = SGL[2]

    # Desvios padrão
    std_e = station_std[0, 0]
    std_n = station_std[0, 1]
    std_u = station_std[0, 2]

    # Calcula o RMSE ponderado pelos desvios padrão
    rmse_e = calculate_rmse(de, (std_e + std_e.mean()) / 2)
    rmse_n = calculate_rmse(dn, (std_n + std_n.mean()) / 2)
    rmse_u = calculate_rmse(du, (std_u + std_u.mean()) / 2)
    rmse_planimetrico = np.sqrt(rmse_e**2 + rmse_n**2)

    return rmse_e, rmse_n, rmse_u, rmse_planimetrico

# Função principal para processar os dados GNSS
def process_gnss_data(meses, estacoes_rbmc, ano, base_path, df_rbmc, df_rbmc_geo):
    # Inicializa a lista para armazenar os resultados
    results = []

    # Itera sobre cada mês e estação RBMC
    for mes in meses:
        for estacao in estacoes_rbmc:
            # Caminho dos arquivos de processamento GNSS
            file_path_gnss = os.path.join(base_path, mes, estacao, 'pos')

            # Encontre todos os arquivos .pos
            gnss_files = glob.glob(os.path.join(file_path_gnss, '*.pos'))

            for filepath in gnss_files:
                try:
                    # Extrair o "day of year"
                    doy = int(filepath.split('_')[-2][-4:-1])

                    # Transformar DOY + ano em data
                    doy_as_date = doy_year_to_date(doy, ano)

                    # Data de referência semanal mais próxima
                    ref_date = get_closest_date(doy_as_date, df_rbmc['Date'].unique())

                    # Coordenadas geodésicas da estação
                    station_geodetic = df_rbmc_geo[
                        (df_rbmc_geo['StationName'] == estacao) & (df_rbmc_geo['Date'] == ref_date)
                    ][['Latitude', 'Longitude', 'Height']].values

                    # Coordenadas cartesianas da estação
                    station_cartesian = df_rbmc[
                        (df_rbmc['StationName'] == estacao) & (df_rbmc['Date'] == ref_date)
                    ][['X', 'Y', 'Z']].values

                    # Desvios padrão da estação
                    station_std = df_rbmc[
                        (df_rbmc['StationName'] == estacao) & (df_rbmc['Date'] == ref_date)
                    ][['StdX', 'StdY', 'StdZ']].values

                    # Se não encontrar coordenadas, pula o processamento
                    if station_geodetic.size == 0 or station_cartesian.size == 0 or station_std.size == 0:
                        print(f"Sem coordenadas para {estacao} em {ref_date}. Pulando...")
                        continue

                    # Processando o arquivo de resultados
                    gnss_data = extract_data(filepath)

                    # Calculando RMSE no sistema geodésico local (SGL)
                    rmse_e, rmse_n, rmse_u, rmse_planimetrico = calculate_rmse_sgl(
                        gnss_data, station_geodetic, station_std, station_cartesian
                    )

                    # Adiciona os resultados à lista
                    results.append({
                        'Estacao': estacao,
                        'Periodo': mes,
                        'DOY': doy,
                        'DataReferencia': ref_date,
                        'RMSE_E': rmse_e,
                        'RMSE_N': rmse_n,
                        'RMSE_U': rmse_u,
                        'RMSE_Planimetrico': rmse_planimetrico
                    })

                except Exception as e:
                    print(f"Erro ao processar arquivo {filepath}: {e}")

    # Cria um DataFrame com os resultados
    df_results = pd.DataFrame(results)

    # Exibe o resumo agrupado por estação e período
    summary = df_results.groupby(['Estacao', 'Periodo']).mean(numeric_only=True)
    print(summary)

    # Salva os resultados em um arquivo CSV
    # # output_file = '/content/drive/My Drive/VMF3/dados/orig/rmse_sgl_summary.csv'
    # output_file = os.path.join(base_path, "rmse_sgl_summary.csv")
    # df_results.to_csv(output_file, index=False)
    # print(f"Resumo salvo em {output_file}")
    
    # Salva os resultados em um arquivo CSV
    # output_file = f'saidas/{scenario}/rmse_summary.csv'
    output_file = os.path.join(sc_outpath,'rmse_summary_enu.csv')
    df_results.to_csv(output_file, index=False)
    print(f"Resumo salvo em {output_file}")


    actual_summary_path = os.path.join(sc_outpath,'rmse_general_summary_enu.csv')
    summary.to_csv(actual_summary_path, index=False)


# Caminho para o arquivo de coordenadas geodésicas das estações RBMC
file_path_rbmc_geo = 'Coordenadas_estacoes_geo.txt'

# Lê os dados de coordenadas geodésicas das estações RBMC
df_rbmc_geo = read_rbmc_geodetic_coordinates(file_path_rbmc_geo)

# Chama a função para processar os dados GNSS e calcular o RMSE no sistema geodésico local
process_gnss_data(meses, estacoes_rbmc, ano, base_path, df_rbmc, df_rbmc_geo)
# Out:
# /tmp/ipykernel_17330/1800988401.py:46: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, header=None, names=columns)
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/BRAZ/pos/braz0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/CUIB/pos/cuib0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/UFPR/pos/ufpr0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/NAUS/pos/naus0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POAL/pos/poal0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/PERC/pos/perc0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/ONRJ/pos/onrj0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SSA1/pos/ssa10311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/SAGA/pos/saga0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0141_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0151_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0161_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0171_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0181_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0191_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0201_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0211_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0221_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0231_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0241_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0251_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0261_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0271_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0281_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0291_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0301_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/VERAO/POLI/pos/poli0311_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1831_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1841_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1851_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1861_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1871_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1881_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1891_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1901_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1911_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1921_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1931_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1941_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1951_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1961_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1971_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1981_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz1991_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2001_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2011_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2021_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2031_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2041_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2051_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2061_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2071_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2081_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2091_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2101_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2111_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2121_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/BRAZ/pos/braz2131_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1831_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1841_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1851_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1861_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1871_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1881_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1891_res_events.pos: invalid literal for int() with base 10: 're'
# Erro ao processar arquivo /home/gnss_data/saidas/demo5_2h_orig/INVERNO/CUIB/pos/cuib1901_res_events.pos: invalid literal for int() with base 10: 're'
#                    DOY    RMSE_E    RMSE_N    RMSE_U  RMSE_Planimetrico
# Estacao Periodo
# BRAZ    INVERNO  198.0  0.186698  0.159116  0.393831           0.253671
#         VERAO     21.0  0.192477  0.173110  0.473029           0.266061
# CUIB    INVERNO  186.5  0.265672  0.085251  0.235523           0.279746
#         VERAO     16.0  0.255118  0.092995  0.360715           0.274805
# NAUS    VERAO     16.0  0.128589  0.116544  0.355499           0.176522
# ONRJ    VERAO     16.0  0.218628  0.103018  0.378098           0.245891
# PERC    VERAO     16.0  0.237727  0.189442  0.330406           0.311207
# POAL    VERAO     16.0  0.214500  0.143050  0.349073           0.261667
# POLI    VERAO     16.0  0.208192  0.141412  0.429416           0.256049
# SAGA    VERAO     16.0  0.271389  0.137087  0.456280           0.307711
# SSA1    VERAO     16.0  0.349229  0.153069  0.337560           0.386081
# UFPR    VERAO     16.0  0.267963  0.124190  0.421147           0.298388
# Resumo salvo em saidas/demo5_2h_orig/rmse_summary_enu.csv

# %%
import pandas as pd

# Caminho para o arquivo previamente gerado
output_file = os.path.join(base_path, "rmse_sgl_summary.csv")

# Verifica se o arquivo existe
if os.path.exists(output_file):
    # Carrega o arquivo CSV como DataFrame
    df_results = pd.read_csv(output_file)
    print("Arquivo carregado com sucesso!")
else:
    print(f"O arquivo {output_file} não foi encontrado. É necessário executar o processamento novamente.")
# Out:
# O arquivo /home/gnss_data/saidas/demo5_2h_orig/rmse_sgl_summary.csv não foi encontrado. É necessário executar o processamento novamente.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Configurações para os histogramas
def plot_histograms(data, period, title, save_path, ymax):
    # Estações RBMC
    stations = np.sort(data['Estacao'].unique())  # Ordena as estações em ordem alfabética

    # Define o índice das estações
    x = np.arange(len(stations))

    # Largura das colunas
    width = 0.25

    # Valores RMSE para cada coordenada, ordenados pelas estações
    rmse_x = [data[data['Estacao'] == station]['RMSE_E'].mean() for station in stations]
    rmse_y = [data[data['Estacao'] == station]['RMSE_N'].mean() for station in stations]
    rmse_z = [data[data['Estacao'] == station]['RMSE_U'].mean() for station in stations]

    # Criação do gráfico
    fig, ax = plt.subplots(figsize=(12, 6))

    # Barras para cada RMSE
    ax.bar(x - width, rmse_x, width, label='RMSE_E(m)', color='blue')
    ax.bar(x, rmse_y, width, label='RMSE_N(m)', color='orange')
    ax.bar(x + width, rmse_z, width, label='RMSE_U(m)', color='green')

    # Configuração dos rótulos e título
    ax.set_xlabel('Estações RBMC', fontsize=12)
    ax.set_ylabel('RMSE (m)', fontsize=12)
    ax.set_title(title, fontsize=16)
    ax.set_xticks(x)
    ax.set_xticklabels(stations, rotation=45, fontsize=10)
    ax.legend(fontsize=10)
    ax.grid(axis='y', linestyle='--', alpha=0.7)

    # Define o mesmo limite no eixo Y para todos os gráficos
    ax.set_ylim(0, ymax)

    # Ajusta layout
    plt.tight_layout()

    # Salva a figura
    plt.savefig(save_path)
    print(f"Histograma salvo em: {save_path}")
    plt.show()

# Filtra os dados para os períodos VERÃO (janeiro) e INVERNO (julho)
data_verao = df_results[df_results['Periodo'] == 'VERAO']
data_inverno = df_results[df_results['Periodo'] == 'INVERNO']

# Calcula o valor máximo global de RMSE
rmse_max = max(
    data_verao[['RMSE_E', 'RMSE_N', 'RMSE_U']].max().max(),
    data_inverno[['RMSE_E', 'RMSE_N', 'RMSE_U']].max().max()
)

# Gera o histograma para janeiro (VERÃO)
plot_histograms(
    data=data_verao,
    period='VERAO',
    title='RMSE (Verão)',
    # save_path=f'/content/drive/My Drive/VMF3/dados/{scenario}/rmse_histogram_janeiro.png',
    save_path = os.path.join(sc_charts_outpath,'rmse_janeiro_enu.png'),
    ymax=rmse_max
)

# Gera o histograma para julho (INVERNO)
plot_histograms(
    data=data_inverno,
    period='INVERNO',
    title='RMSE (Inverno)',
    # save_path=f'/content/drive/My Drive/VMF3/dados/{scenario}/rmse_histogram_julho.png',
    save_path = os.path.join(sc_charts_outpath,'rmse_julho_enu.png'),
    ymax=rmse_max
)
# Out:
# Histograma salvo em: charts/demo5_2h_orig/rmse_janeiro_enu.png
# Histograma salvo em: charts/demo5_2h_orig/rmse_julho_enu.png

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Configurações gerais de estilo
sns.set(style="whitegrid")

# Filtra os dados para os períodos de interesse
df_verao = df_results[df_results['Periodo'] == 'VERAO']
df_inverno = df_results[df_results['Periodo'] == 'INVERNO']

# Calcula o valor máximo global de RMSE para padronizar o eixo Y
rmse_max_global = df_results[['RMSE_E', 'RMSE_N', 'RMSE_U']].max().max()

# Função para criar boxplots para um período específico
def create_boxplot(data, periodo, output_file=None, ymax=None):
    # Ordena as estações em ordem alfabética
    data = data.sort_values(by='Estacao')

    # Transforma os dados no formato longo para facilitar o uso no Seaborn
    data_long = data.melt(
        id_vars=['Estacao'],
        value_vars=['RMSE_E', 'RMSE_N', 'RMSE_U'],
        var_name='Coordenada',
        value_name='RMSE'
    )

    # Substitui os nomes das coordenadas para incluir o sufixo (m)
    data_long['Coordenada'] = data_long['Coordenada'].replace({
        'RMSE_E': 'RMSE_E(m)',
        'RMSE_N': 'RMSE_N(m)',
        'RMSE_U': 'RMSE_U(m)'
    })

    # Cria o boxplot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='Estacao', y='RMSE', hue='Coordenada', data=data_long, palette='Set2')

    # Configurações do gráfico
    plt.title(f'Boxplots de RMSE ({periodo})', fontsize=16)
    plt.xlabel('Estações RBMC', fontsize=14)
    plt.ylabel('RMSE (m)', fontsize=14)
    plt.xticks(rotation=45, fontsize=12)
    plt.legend(title='Coordenada', fontsize=12)

    # Ajusta o limite do eixo Y
    if ymax is not None:
        plt.ylim(0, ymax)

    # Salva o gráfico, se necessário
    if output_file:
        plt.savefig(output_file, dpi=300, bbox_inches='tight')

    # Exibe o gráfico
    plt.show()


# Gera os boxplots para janeiro (verão)
boxplot_verao_path = os.path.join(sc_charts_outpath,'boxplot_verao_enu.png')
create_boxplot(df_verao, 'Verão', boxplot_verao_path, ymax=rmse_max_global)

# Gera os boxplots para julho (inverno)
boxplot_inverno_path = os.path.join(sc_charts_outpath,'boxplot_inverno_enu.png')
create_boxplot(df_inverno, 'Inverno', boxplot_inverno_path, ymax=rmse_max_global)

# %%
# boxplot textual
input_dfs = {
    'inverno': df_inverno,
    'verao': df_verao
}

for column in ['RMSE_E', 'RMSE_N', 'RMSE_U']:
    for periodo, df in input_dfs.items():
        outpath = os.path.join(sc_outpath,f'boxplot_enu_{periodo}_{column}.csv')
        textual_boxplot(df, column, outpath)
        
        for station in estacoes_rbmc:
            
            outpath = os.path.join(sc_outpath,f'boxplot_enu_{periodo}_{column}_{station}.csv')
            textual_boxplot(df, column, outpath, subset_column='Estacao', subset_value=station)

# %%
# Gera os boxplots para janeiro (verão) com limite máximo no eixo Y de 0.4
create_boxplot(df_verao, 'Verão', boxplot_verao_path.replace('.png','_v2.png'), ymax=0.4)

# Gera os boxplots para julho (inverno) com limite máximo no eixo Y de 0.4
create_boxplot(df_inverno, 'Inverno', boxplot_inverno_path.replace('.png','_v2.png'), ymax=0.4)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Função para remover outliers
def remove_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# Configurações para os histogramas
def plot_histograms(data, stations, rmse_x, rmse_y, rmse_z, title, save_path, y_max):
    # Define o índice das estações
    x = np.arange(len(stations))

    # Largura das colunas
    width = 0.25

    # Criação do gráfico
    fig, ax = plt.subplots(figsize=(12, 6))

    # Barras para cada RMSE
    ax.bar(x - width, rmse_x, width, label='RMSE_X(m)', color='blue')
    ax.bar(x, rmse_y, width, label='RMSE_Y(m)', color='orange')
    ax.bar(x + width, rmse_z, width, label='RMSE_Z(m)', color='green')

    # Configuração dos rótulos e título
    ax.set_xlabel('Estações RBMC', fontsize=12)
    ax.set_ylabel('RMSE (m)', fontsize=12)
    ax.set_title(title, fontsize=16)
    ax.set_xticks(x)
    ax.set_xticklabels(stations, rotation=45, fontsize=10)
    ax.set_ylim(0, y_max)  # Define a escala fixa para o eixo Y
    ax.legend(fontsize=10)
    ax.grid(axis='y', linestyle='--', alpha=0.7)

    # Ajusta layout
    plt.tight_layout()

    # Salva a figura
    plt.savefig(save_path)
    print(f"Histograma salvo em: {save_path}")
    plt.show()

# Remove outliers para todas as colunas
data_clean = remove_outliers(df_results, 'RMSE_E')
data_clean = remove_outliers(data_clean, 'RMSE_N')
data_clean = remove_outliers(data_clean, 'RMSE_U')

# Filtra os dados para os períodos VERÃO (janeiro) e INVERNO (julho)
data_verao = data_clean[data_clean['Periodo'] == 'VERAO']
data_inverno = data_clean[data_clean['Periodo'] == 'INVERNO']

# Estações RBMC e valores RMSE para ambos os períodos
stations = data_clean['Estacao'].unique()
stations.sort()

rmse_verao_x = [data_verao[data_verao['Estacao'] == station]['RMSE_E'].mean() for station in stations]
rmse_verao_y = [data_verao[data_verao['Estacao'] == station]['RMSE_N'].mean() for station in stations]
rmse_verao_z = [data_verao[data_verao['Estacao'] == station]['RMSE_U'].mean() for station in stations]

rmse_inverno_x = [data_inverno[data_inverno['Estacao'] == station]['RMSE_E'].mean() for station in stations]
rmse_inverno_y = [data_inverno[data_inverno['Estacao'] == station]['RMSE_N'].mean() for station in stations]
rmse_inverno_z = [data_inverno[data_inverno['Estacao'] == station]['RMSE_U'].mean() for station in stations]

# Determina o limite máximo do eixo Y
y_max = max(
    max(rmse_verao_x + rmse_verao_y + rmse_verao_z),
    max(rmse_inverno_x + rmse_inverno_y + rmse_inverno_z),
) * 1.1  # Adiciona 10% de margem

# Gera o histograma para janeiro (VERÃO)
plot_histograms(
    data=data_verao,
    stations=stations,
    rmse_x=rmse_verao_x,
    rmse_y=rmse_verao_y,
    rmse_z=rmse_verao_z,
    title='RMSE (Verão) - Sem Outliers',
    # save_path=f'/content/drive/My Drive/VMF3/dados/{scenario}/rmse_histogram_janeiro_Sem outliers.png',
    save_path = os.path.join(sc_charts_outpath,'rmse_janeiro_enu_sem_outliers.png'),
    y_max=0.4 #y_max
)

# Gera o histograma para julho (INVERNO)
plot_histograms(
    data=data_inverno,
    stations=stations,
    rmse_x=rmse_inverno_x,
    rmse_y=rmse_inverno_y,
    rmse_z=rmse_inverno_z,
    title='RMSE (Inverno) - Sem Outliers',
    # save_path=f'/content/drive/My Drive/VMF3/dados/{scenario}/rmse_histogram_julho_Sem outliers.png',
    save_path=os.path.join(sc_charts_outpath,'rmse_julho_enu_sem_outliers.png'),
    y_max=0.4 #y_max
)
# Out:
# Histograma salvo em: charts/demo5_2h_orig/rmse_janeiro_enu_sem_outliers.png
# Histograma salvo em: charts/demo5_2h_orig/rmse_julho_enu_sem_outliers.png
